# %%
# !pip install pandas
# !pip install openpyxl
# !pip install folium
# !pip install geopy
# Out:
# Collecting pandas
#   Using cached pandas-1.4.2-cp39-cp39-macosx_10_9_x86_64.whl (11.1 MB)
# Collecting pytz>=2020.1
#   Using cached pytz-2022.1-py2.py3-none-any.whl (503 kB)
# Requirement already satisfied: numpy>=1.18.5 in /opt/anaconda3/envs/hyper/lib/python3.9/site-packages (from pandas) (1.22.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/anaconda3/envs/hyper/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/hyper/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Installing collected packages: pytz, pandas
# Successfully installed pandas-1.4.2 pytz-2022.1
# Collecting openpyxl
#   Using cached openpyxl-3.0.9-py2.py3-none-any.whl (242 kB)
# Collecting et-xmlfile
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.0.9
# Collecting folium
#   Using cached folium-0.12.1.post1-py2.py3-none-any.whl (95 kB)
# Collecting branca>=0.3.0
#   Using cached branca-0.5.0-py3-none-any.whl (24 kB)
# Collecting requests
#   Using cached requests-2.27.1-py2.py3-none-any.whl (63 kB)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/hyper/lib/python3.9/site-packages (from folium) (1.22.3)
# Requirement already satisfied: jinja2>=2.9 in /opt/anaconda3/envs/hyper/lib/python3.9/site-packages (from folium) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/hyper/lib/python3.9/site-packages (from jinja2>=2.9->folium) (2.0.1)
# Collecting idna<4,>=2.5
#   Using cached idna-3.3-py3-none-any.whl (61 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/hyper/lib/python3.9/site-packages (from requests->folium) (2021.10.8)
# Collecting urllib3<1.27,>=1.21.1
#   Using cached urllib3-1.26.9-py2.py3-none-any.whl (138 kB)
# Collecting charset-normalizer~=2.0.0
#   Using cached charset_normalizer-2.0.12-py3-none-any.whl (39 kB)
# Installing collected packages: urllib3, idna, charset-normalizer, requests, branca, folium
# Successfully installed branca-0.5.0 charset-normalizer-2.0.12 folium-0.12.1.post1 idna-3.3 requests-2.27.1 urllib3-1.26.9
# Collecting geopy
#   Using cached geopy-2.2.0-py3-none-any.whl (118 kB)
# Collecting geographiclib<2,>=1.49
#   Using cached geographiclib-1.52-py3-none-any.whl (38 kB)
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-1.52 geopy-2.2.0

# %%
import pandas as pd
import glob
import os

# %%
from geopy.geocoders import Nominatim
n = input("현재 위치를 적어주세요:")
app = Nominatim(user_agent='tutorial')
location = app.geocode('{n}'.format(n=n))
print(location.latitude, location.longitude)
# Out:
# 현재 위치를 적어주세요:영통역
# 37.2541611 127.0742492

# %%
df = pd.read_csv("DataSets/DataFrame.csv", engine='python', encoding='utf-8')

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', '상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명',
#        '상권업종중분류코드', '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명',
#        '시도코드', '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명',
#        '지번코드', '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명',
#        '건물본번지', '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보',
#        '층정보', '호정보', '경도', '위도', 'Unnamed: 0'],
#       dtype='object')

# %%
set(list(df['상권업종대분류명']))
# Out:
# {'관광/여가/오락', '부동산', '생활서비스', '소매', '숙박', '스포츠', '음식', '학문/교육'}

# %%
set(list(df['상권업종중분류명']))
# Out:
# {'PC/오락/당구/볼링등',
#  '가구소매',
#  '가방/신발/액세서리',
#  '가전제품소매',
#  '가정/주방/인테리어',
#  '개인/가정용품수리',
#  '개인서비스',
#  '건강/미용식품',
#  '경마/경륜/성인오락',
#  '광고/인쇄',
#  '기타서비스업',
#  '기타음식업',
#  '기타판매업',
#  '놀이/여가/취미',
#  '닭/오리요리',
#  '대중목욕탕/휴게',
#  '대행업',
#  '도서관/독서실',
#  '모텔/여관/여인숙',
#  '무도/유흥/가무',
#  '물품기기대여',
#  '민박/하숙',
#  '법무세무회계',
#  '별식/퓨전요리',
#  '부동산관련서비스',
#  '부동산중개',
#  '부페',
#  '분식',
#  '분양',
#  '사무/문구/컴퓨터',
#  '사진',
#  '사진/광학/정밀기기소매',
#  '선물/팬시/기념품',
#  '세탁/가사서비스',
#  '스포츠/운동',
#  '시계/귀금속소매',
#  '실내운동시설',
#  '실외운동시설',
#  '애견/애완/동물',
#  '양식',
#  '연극/영화/극장',
#  '예술품/골동품/수석/분재',
#  '예식/의례/관혼상제',
#  '요가/단전/마사지',
#  '운동/경기용품소매',
#  '운송/배달/택배',
#  '운영관리시설',
#  '유스호스텔',
#  '유아교육',
#  '유아용품',
#  '유흥주점',
#  '음/식료품소매',
#  '음식배달서비스',
#  '의복의류',
#  '의약/의료품소매',
#  '이/미용/건강',
#  '인력/고용/용역알선',
#  '일식/수산물',
#  '자동차/이륜차',
#  '자동차/자동차용품',
#  '장례/묘지',
#  '제과제빵떡케익',
#  '종교용품판매',
#  '종합소매점',
#  '주유소/충전소',
#  '주택수리',
#  '중고품소매/교환',
#  '중식',
#  '책/서적/도서',
#  '철물/난방/건설자재소매',
#  '취미/오락관련소매',
#  '캠프/별장/펜션',
#  '커피점/카페',
#  '패스트푸드',
#  '페인트/유리제품소매',
#  '평가/개발/관리',
#  '학문교육기타',
#  '학원-보습교습입시',
#  '학원-어학',
#  '학원-예능취미체육',
#  '학원-음악미술무용',
#  '학원-자격/국가고시',
#  '학원-창업취업취미',
#  '학원-컴퓨터',
#  '학원기타',
#  '한식',
#  '행사/이벤트',
#  '호텔/콘도',
#  '화장품소매'}

# %%
set(list(df['상권업종소분류명']))
# Out:
# {'LPG판매',
#  nan,
#  '가구수리',
#  '가구판매-돌침대',
#  '가구판매-등가구',
#  '가구판매-사무용가구',
#  '가구판매-수입가구',
#  '가구판매-응접세트',
#  '가구판매-장농',
#  '가구판매-침대전문',
#  '가발판매',
#  '가방/가죽제품소매',
#  '가방구두수전',
#  '가방대여',
#  '가사도우미알선',
#  '가스레인지판매',
#  '가스설비',
#  '가전제품수리',
#  '가정용가구/기기임대',
#  '가정용연료소매',
#  '가죽/모피수선',
#  '가죽/모피의류',
#  '가죽모피세탁',
#  '간판제작종합',
#  '갈비/삼겹살',
#  '갈치/생선구이',
#  '개인/가정용품수리-종합',
#  '건강/헬스용품',
#  '건강보조기구판매',
#  '건강식품판매',
#  '건강원',
#  '건과류판매',
#  '건물분양-종합',
#  '건어물상',
#  '건축백화점',
#  '검도도장',
#  '게이트볼장',
#  '게임룸',
#  '게장전문',
#  '결혼상담소',
#  '경보기판매',
#  '경비행기',
#  '고객관리대행',
#  '고기부페',
#  '고등어전문',
#  '고서적판매',
#  '고속도로휴게소',
#  '고시원',
#  '곡물소매',
#  '골동품수리',
#  '골동품판매',
#  '골프용품판매',
#  '골프장',
#  '골프회원권거래소',
#  '곰장어전문',
#  '곱창/양구이전문',
#  '공연티켓예매',
#  '공예품판매',
#  '관광/민예품/선물용품소매',
#  '관광/유흥주점',
#  '광고대행-전화번호부',
#  '광고물제작',
#  '광고물제작-종합',
#  '광촉매판매',
#  '광택전문',
#  '교복판매',
#  '구내식당/자급식음식점',
#  '구두제화/캐주얼화',
#  '구판장/직판장',
#  '국/찌개배달',
#  '국도휴게소',
#  '국수/만두/칼국수',
#  '국제회의용역',
#  '굴요리전문',
#  '그릇판매',
#  '그림/액자판매',
#  '극장식유흥주점',
#  '금고수리',
#  '금고판매',
#  '금연관련제품판매',
#  '금은방',
#  '기념패/휘장',
#  '기능성신발판매',
#  '기독교서적판매',
#  '기사식당',
#  '기원',
#  '기타경기후원업/경기단체',
#  '기타고기요리',
#  '기타실내운동시설',
#  '기타실외운동시설',
#  '기타오락관련산업',
#  '기타운영설비',
#  '기타일반유흥주점',
#  '기타전문서양음식점',
#  '김치판매',
#  '꼬치구이전문점',
#  '꽃꽂이(대행)',
#  '꽃집/꽃배달',
#  '나이트클럽',
#  '낙지/오징어',
#  '낚시용품판매',
#  '낚시터',
#  '남성미용실',
#  '남성의류전문점',
#  '냉동식품판매',
#  '냉면집',
#  '냉온수기소독/수리',
#  '네비게이션판매',
#  '노래방',
#  '노래방기기판매',
#  '노점/유사이동판매',
#  '녹즙판매',
#  '놀이방',
#  '농기구수리',
#  '농기구판매',
#  '농자재판매',
#  '눈썰매장',
#  '다이아몬드매매',
#  '다이어트상품판매',
#  '단식원',
#  '단전호흡',
#  '닭갈비전문',
#  '닭내장/닭발요리',
#  '닭도리탕전문',
#  '닭집',
#  '당구장',
#  '대서소',
#  '도너츠전문',
#  '도료염료',
#  '도면제작대행',
#  '도서/만화대여',
#  '도시락전문점',
#  '도자기대여',
#  '독서실',
#  '돈가스전문점',
#  '돌구이요리전문',
#  '돌솥/비빕밥전문점',
#  '동남아음식전문점',
#  '동물약품판매',
#  '동화구연',
#  '두부요리전문',
#  '두유판매',
#  '드라이아이스판매',
#  '등산용품판매',
#  '등세공품판매',
#  '디스플레이대행',
#  '떡/한과집',
#  '떡볶이전문',
#  '떡전문',
#  '라면김밥분식',
#  '락카페',
#  '래프팅',
#  '레크레이션지도/상담',
#  '렌트카',
#  '로바다야끼',
#  '롤러스케이트장',
#  '룸살롱/단란주점',
#  '리본공예판매',
#  '맞춤양복/양복점',
#  '맞춤양장/양장점',
#  '매운탕전문',
#  '머리고기전문',
#  '면세백화점',
#  '모텔/여관/여인숙',
#  '목욕업-찜질방',
#  '목재대여',
#  '목제품판매',
#  '묘지관리-종합',
#  '무도유흥주점-종합',
#  '무도장',
#  '무전기(판매/수리)',
#  '문서송달대행',
#  '물물교환센타',
#  '물수건대여',
#  '물품감정서비스',
#  '물품대여종합',
#  '미곡상',
#  '미싱판매',
#  '미용실-어린이',
#  '미장타일도배도장',
#  '민물장어전문',
#  '민박/하숙',
#  '민속주점',
#  '바닷가재/게요리전문',
#  '바둑/장기용품판매',
#  '바베큐전문',
#  '박제표본',
#  '반찬가게',
#  '발/네일케어',
#  '방앗간/정미소',
#  '배관난방보일러',
#  '백화점',
#  '버섯전문점',
#  '번역/통역서비스',
#  '번지점프',
#  '법무관련서비스-종합',
#  '법복(승복)판매',
#  '보드게임카페',
#  '보리밥전문',
#  '보석감정',
#  '보일러/냉난방용품',
#  '보청기판매',
#  '복권판매',
#  '복사대행',
#  '복싱도장',
#  '복전문',
#  '볼링용품판매',
#  '볼링장',
#  '부대찌개/섞어찌개',
#  '부동산감정평가',
#  '부동산소유권조사',
#  '부동산신탁',
#  '부동산자문',
#  '부동산중개',
#  '분재판매',
#  '불교서적판매',
#  '불닭전문',
#  '붕어찜전문',
#  '블럭놀이방',
#  '비데판매',
#  '비디오/오디오테이프대여',
#  '비디오감상실',
#  '비디오카메라대여',
#  '비만/피부관리',
#  '비즈공예',
#  '비행훈련원',
#  '빠/카페/스탠드빠',
#  '사격장',
#  '사료소매',
#  '사무/문구용품',
#  '사무기기대여',
#  '사무대리서비스',
#  '사무실분양',
#  '사무용기기소매',
#  '사업경영상담',
#  '사업중개업',
#  '사우나/증기탕/온천',
#  '사주카페',
#  '사진/광학/정밀기기소매',
#  '사진/원고/기록물대여',
#  '사진관',
#  '사철탕전문',
#  '삼계탕전문',
#  '상가분양',
#  '상업사진',
#  '상품권판매',
#  '상품전시',
#  '상품포장',
#  '샌드위치전문점',
#  '생과일주스전문점',
#  '생과자점',
#  '생수판매',
#  '생식판매',
#  '생활용품대여',
#  '생활용품판매',
#  '생활정보제공서비스',
#  '샤브샤브전문',
#  '서바이벌게임장',
#  '서예/서화/미술',
#  '서적/신문소매',
#  '서점',
#  '석궁용품판매',
#  '석궁장',
#  '선물용품판매',
#  '선식판매',
#  '설렁탕집',
#  '섬유/직물/주단',
#  '성인용품판매',
#  '세차장',
#  '세탁기구판매',
#  '세탁대행',
#  '세탁소/빨래방',
#  '셔츠/내의/속옷',
#  '셔터/새시판매',
#  '소주방/포장마차',
#  '소파침대카펫트세탁',
#  '솜틀집',
#  '수도설비',
#  '수렵장관리운영',
#  '수산물소매',
#  '수산물전문음식점-종합',
#  '수상스키',
#  '수상운동용품판매',
#  '수석판매',
#  '수영용품판매',
#  '수영장',
#  '수입가전제품판매',
#  '수입담배판매',
#  '수입자동차판매',
#  '수입중고자동차판매',
#  '수입품판매점',
#  '수족관',
#  '수퍼마켓',
#  '순대전문점',
#  '순두부전문',
#  '스낵',
#  '스케이트장',
#  '스쿼시장',
#  '스키장',
#  '스키장비판매',
#  '스킨스쿠버강습',
#  '스테이크전문점',
#  '스티커사진방',
#  '스파게티전문점',
#  '스포츠마사지',
#  '스포츠센터',
#  '승마장',
#  '시계/귀금속',
#  '시계방',
#  '시장/종합상가',
#  '시험정보안내',
#  '식료품점',
#  '식용유판매',
#  '식자재판매',
#  '신발세탁',
#  '신발소매',
#  '신용조사/흥신소',
#  '신용카드조회기판매',
#  '실내골프연습장',
#  '실내궁도장',
#  '실내낚시',
#  '실내놀이터-유아',
#  '실내사격장',
#  '실내수영장',
#  '실내스케이트장',
#  '실내야구연습장',
#  '실내테니스장',
#  '실외골프연습장',
#  '실외궁도장',
#  '실외야구연습장',
#  '심부름센터',
#  '심야전기보일러판매',
#  '십자수/뜨개',
#  '쌈밥전문',
#  '아구전문',
#  '아동복판매',
#  '아이스크림판매',
#  '아케이드/쇼핑센타',
#  '악기대여',
#  '악기수선',
#  '악기판매',
#  '안경원',
#  '안마시술소',
#  '안전보호구판매',
#  '애견/애완/동물사육판매',
#  '애견카페',
#  '애완동물 미용실',
#  '액세서리수선',
#  '액세서리판매',
#  '액자점',
#  '야구장',
#  '야식집',
#  '양품점',
#  '어린이집',
#  '어물상',
#  '어판장',
#  '얼음가게',
#  '업소용가전제품',
#  '에어컨수리/설치',
#  '여성내의전문점',
#  '여성미용실',
#  '여성의류전문점',
#  '연극/음악/예술관련기타',
#  '연극공연/영화제작용품임대',
#  '연예인대리업',
#  '연탄판매',
#  '열쇠제작',
#  '열쇠판매/수리',
#  '영사기판매',
#  '예복/웨딩드레스',
#  '예술품/골동품소매',
#  '예식장/예식서비스',
#  '예절지도',
#  '오디오전문점',
#  '오락/스포츠용품대여',
#  '오락게임기구/장난감소매',
#  '오락용사격장',
#  '오리고기전문',
#  '오토바이판매/수리',
#  '옷수선',
#  '옻닭전문',
#  '완구점',
#  '외국서적판매',
#  '요가/단식',
#  '욕탕업-종합',
#  '우동전문점',
#  '우산/우의판매',
#  '우유판매',
#  '우체국/우편물취급소',
#  '우표/공중전화카드수집상',
#  '운동/경기용품',
#  '운동/코치학교',
#  '운동경기협회',
#  '운명감정작명',
#  '운전연수전문',
#  '유과판매',
#  '유기농식품판매',
#  '유니폼/맞춤복/단체복',
#  '유도장',
#  '유류판매',
#  '유리/거울판매',
#  '유리/페인트/철물건축자재',
#  '유리창호',
#  '유산균아이스크림전문',
#  '유스호스텔',
#  '유아/임부복',
#  '유아교육기관기타',
#  '유아식품판매',
#  '유아용품/장난감대여판매',
#  '유아용품판매',
#  '육류소매',
#  '음반/테이프/CD',
#  '음식점-일식',
#  '음식점-초밥전문',
#  '음식출장조달',
#  '음악감상',
#  '응원기획',
#  '의료용품소매',
#  '의류/한복대여',
#  '의약품소매',
#  '의족/의수판매',
#  '이동도서관운영',
#  '이민유학알선',
#  '이벤트기획',
#  '이벤트용품판매',
#  '이삿짐보관',
#  '이종격투기',
#  '인공암벽',
#  '인라인스케이트판매',
#  '인력공급/고용알선',
#  '인삼제품판매',
#  '인쇄종합',
#  '인장/도장',
#  '인터넷PC방',
#  '인테리어/욕실용품/커튼',
#  '일반가구소매',
#  '일반가전제품',
#  '일반의류',
#  '잉크충전',
#  '자동차부품판매',
#  '자동차유리전문점',
#  '자동차장식품판매',
#  '자동차정비/카센타',
#  '자동차판매',
#  '자동판매기운영',
#  '자전거판매',
#  '자전거판매/수리',
#  '작곡',
#  '잡지/신문소매',
#  '잡화점',
#  '장식품대여',
#  '장의사/관련서비스-종합',
#  '재봉용품판매',
#  '재첩국전문',
#  '재활용/고물수집',
#  '저울판매',
#  '전단지배포대행',
#  '전자오락기구판매',
#  '전자오락실',
#  '전통찻집/인삼찻집',
#  '전화기판매',
#  '정보통신기기수리',
#  '정수기연수기',
#  '정육점',
#  '정통양식/경양식',
#  '제과재료판매',
#  '제과점',
#  '제기용품판매',
#  '제사음식',
#  '조감도/투시도전문',
#  '조개구이전문',
#  '조립모형소매',
#  '조립식앵글판매',
#  '조립칸막이/파티션',
#  '조명기구/전기용품',
#  '조합/연금매장',
#  '족발/보쌈전문',
#  '종교서적판매',
#  '종교용품판매',
#  '종교용품판매-기독교',
#  '종교용품판매-불교',
#  '종교용품판매-천주교',
#  '종합부페',
#  '종합소매',
#  '종합이삿짐대행',
#  '주말농장',
#  '주방가구판매',
#  '주방용품',
#  '주유소',
#  '주차장운영',
#  '주택공급',
#  '주택수리종합',
#  '죽전문점',
#  '중고가전가구',
#  '중고명품판매교환',
#  '중고서적판매',
#  '중고자동차판매',
#  '중고타이어판매',
#  '중국음식/중국집',
#  '지도제작',
#  '지도판매',
#  '지물재단',
#  '지물판매',
#  '지압원',
#  '지역정보지',
#  '지점토판매',
#  '진열장판매',
#  '징기스칸요리전문',
#  '찐빵전문',
#  '찜닭전문점',
#  '차량가스충전소',
#  '차량연료소매-종합',
#  '차트제작',
#  '참치전문점',
#  '채식/한식부페',
#  '천주교서적판매',
#  '철물/건설자재소매',
#  '철판구이요리전문',
#  '청과물소매',
#  '청바지판매',
#  '청소/소독',
#  '체육관',
#  '체형미교실',
#  '초상화제작',
#  '총포상',
#  '추어탕전문',
#  '축구장',
#  '출장파티/연회대행',
#  '침구/수예품',
#  '카레전문점',
#  '카메라판매',
#  '카오디오전문',
#  '카페트판매',
#  '캐릭터상품',
#  '캐쥬얼/스포츠의류',
#  '캠프/별장/펜션',
#  '커피전문점/카페/다방',
#  '컴퓨터/사무용기기종합',
#  '컴퓨터/주변기기',
#  '컴퓨터대여',
#  '컴퓨터서적판매',
#  '컴퓨터수리',
#  '컴퓨터입력대행',
#  '컴퓨터전문매장',
#  '컴퓨터프로그램판매',
#  '컴퓨터학원',
#  '케익전문점',
#  '쿵후도장',
#  '퀼트전문',
#  '킥복싱',
#  '타이어판매',
#  '탁구장',
#  '탐정/경호',
#  '탕수육전문점',
#  '태권도장',
#  '태양열온수기판매',
#  '택견도장',
#  '테니스장',
#  '토산품/기념품점',
#  '토스트전문',
#  '토종닭전문',
#  '통신판매',
#  '특수복판매',
#  '특수사진기',
#  '파라솔판매',
#  '파전전문',
#  '패러글라이딩',
#  '패밀리레스토랑',
#  '패션디자인',
#  '패스트푸드',
#  '페인트/유리제품소매',
#  '편의점',
#  '편집대행',
#  '폐백전문',
#  '포켓볼장',
#  '표구점',
#  '풋살경기장',
#  '풍선도소매',
#  '퓨전음식전문',
#  '프로골프',
#  '프로권투',
#  '프로스포츠경기운영',
#  '프로야구',
#  '프로축구',
#  '피아노/바이올린/기타',
#  '피아노운반',
#  '피아노조율',
#  '피자전문',
#  '필름판매점',
#  '필체감정',
#  '학습지보급',
#  '학원(종합)',
#  '학원-TV기술',
#  '학원-가요',
#  '학원-간판디자인',
#  '학원-간호조무사',
#  '학원-건축토목기술',
#  '학원-검정고시',
#  '학원-경리',
#  '학원-경영',
#  '학원-경찰',
#  '학원-공예',
#  '학원-공인중개사',
#  '학원-관광통역',
#  '학원-광고디자인',
#  '학원-국가고시',
#  '학원-국악',
#  '학원-기계/금형기술',
#  '학원-기계고시',
#  '학원-기억법',
#  '학원-기타',
#  '학원-꽃꽃이',
#  '학원-냉동열관리',
#  '학원-네일아트',
#  '학원-도배',
#  '학원-동물사육',
#  '학원-디스플레이',
#  '학원-디자인',
#  '학원-레크리에이션',
#  '학원-마술',
#  '학원-만화영화',
#  '학원-말더듬',
#  '학원-모델',
#  '학원-목공예',
#  '학원-목욕관리사',
#  '학원-무용',
#  '학원-미싱자수',
#  '학원-미용',
#  '학원-바둑',
#  '학원-배관용접',
#  '학원-배우/탤런트',
#  '학원-보석감정',
#  '학원-복장',
#  '학원-분장',
#  '학원-비디오',
#  '학원-사교춤',
#  '학원-사진',
#  '학원-서당',
#  '학원-섬유기술',
#  '학원-속기',
#  '학원-속독',
#  '학원-스튜디어스',
#  '학원-스포츠/재즈댄스',
#  '학원-시계기술학원',
#  '학원-실내운전',
#  '학원-심리변론',
#  '학원-애견미용',
#  '학원-양재',
#  '학원-어린이영어',
#  '학원-에어로빅',
#  '학원-역학',
#  '학원-외국어/어학',
#  '학원-요리',
#  '학원-용접기술',
#  '학원-웅변',
#  '학원-이용',
#  '학원-입시',
#  '학원-자동차운전',
#  '학원-자동차정비',
#  '학원-자수/동양자수',
#  '학원-전기기술',
#  '학원-전자기술',
#  '학원-전자통신',
#  '학원-제과기술',
#  '학원-주산암산부기속셈',
#  '학원-중장비',
#  '학원-지점토',
#  '학원-침술',
#  '학원-칵테일',
#  '학원-캐드',
#  '학원-텔렉스/통신',
#  '학원-펜글씨/한문',
#  '학원-편입',
#  '학원-피부미용',
#  '학원-한복기술',
#  '학원-항공기술',
#  '학원-환경기사',
#  '학원/국가고시',
#  '한국식유흥주점',
#  '한복/갈옷/민속옷',
#  '한식/백반/한정식',
#  '한식부페',
#  '한정식전문',
#  '할인/아동도서',
#  '할인점',
#  '합기도장',
#  '핫도그',
#  '해물부페',
#  '해물찜/탕전문',
#  '해외취업알선',
#  '해장국/감자탕',
#  '핸드폰소매',
#  '행사대행',
#  '향수전문점',
#  '헬스클럽',
#  '현미경/망원경판매',
#  '호스피스',
#  '호신용품판매',
#  '호텔/콘도',
#  '호프/맥주',
#  '혼수전문점',
#  '홈패션',
#  '홍어전문',
#  '화랑',
#  '화방/필방',
#  '화장품판매점',
#  '화폐수집상',
#  '화환/화분대여',
#  '활기원',
#  '황태전문',
#  '황토상품전문점',
#  '회갑연서비스',
#  '횟집',
#  '후라이드/양념치킨',
#  '휴게텔',
#  '휴대폰튜닝'}

# %%
df_coffee = df[(df['상권업종중분류명']=='커피점/카페')]
df_coffee.index = range(len(df_coffee))
print('커피 전문점 점포 수 :', len(df_coffee))
df_coffee.head()
# Out:
# 커피 전문점 점포 수 : 101346
#    Unnamed: 0      상호명    지점명 상권업종대분류명 상권업종중분류명      시도명 시군구명 행정동명         위도  \
# 0          25       나무    NaN       음식   커피점/카페  제주특별자치도  제주시  조천읍  33.456186
# 1          74  한라카페테리아    NaN       음식   커피점/카페  제주특별자치도  제주시  아라동  33.456081
# 2          86    장독대찻집    NaN       음식   커피점/카페  제주특별자치도  제주시   연동  33.487651
# 3         173     커피마마  제주연동점       음식   커피점/카페  제주특별자치도  제주시   연동  33.489192
# 4         193        팡    NaN       음식   커피점/카페  제주특별자치도  제주시  삼양동  33.523128
#
#            경도
# 0  126.710438
# 1  126.556897
# 2  126.492956
# 3  126.490691
# 4  126.583976

# %%
df_food = df[(df['상권업종대분류명']=='음식')]
df_food.index = range(len(df_food))
print('음식 점포 수 :', len(df_food))
df_food.head()
# Out:
# 음식 점포 수 : 1518222
#    Unnamed: 0.1      상가업소번호       상호명    지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0             2  17173846.0  아빠가닭튀기는집    NaN         Q       음식       Q09
# 1             5  17175305.0    숙성1퍼센트    NaN         Q       음식       Q01
# 2             7  28510791.0     해녀촌식당    NaN         Q       음식       Q01
# 3             8  23325473.0     죠스떡볶이    탑동점         Q       음식       Q04
# 4            11  15498703.0     가르텐비어  제주노형점         Q       음식       Q09
#
#   상권업종중분류명 상권업종소분류코드   상권업종소분류명  ...      건물명                     도로명주소  \
# 0     유흥주점    Q09A01      호프/맥주  ...      NaN  제주특별자치도 제주시 한림읍 한림중앙로 26
# 1       한식    Q01A01  한식/백반/한정식  ...      NaN      제주특별자치도 제주시 노형10길 25
# 2       한식    Q01A01  한식/백반/한정식  ...  케이마트가파점   제주특별자치도 서귀포시 대정읍 가파로 76
# 3       분식    Q04A03      떡볶이전문  ...      NaN        제주특별자치도 제주시 임항로 17
# 4     유흥주점    Q09A01      호프/맥주  ...      NaN      제주특별자치도 제주시 월랑로10길 2
#
#       구우편번호    신우편번호  동정보  층정보  호정보          경도         위도 Unnamed: 0
# 0  695932.0  63032.0  NaN  NaN  NaN  126.264860  33.412363        NaN
# 1  690805.0  63083.0  NaN  NaN  NaN  126.479894  33.483335        NaN
# 2  699936.0  63514.0  NaN  NaN  NaN  126.274126  33.166521        NaN
# 3  690801.0  63276.0  NaN  NaN  NaN  126.526797  33.516737        NaN
# 4  690803.0  63097.0  NaN  NaN  NaN  126.476631  33.489020        NaN
#
# [5 rows x 41 columns]

# %%
df_seoul_starbucks = df_coffee[df_coffee['상호명'].str.contains('스타벅스')]
df_seoul_starbucks.index = range(len(df_seoul_starbucks))
print('스타벅스 점포 수 :', len(df_seoul_starbucks))
df_seoul_starbucks.head()
# Out:
# 스타벅스 점포 수 : 1503
#    Unnamed: 0   상호명      지점명 상권업종대분류명 상권업종중분류명      시도명  시군구명  행정동명  \
# 0        3124  스타벅스   제주송악산점       음식   커피점/카페  제주특별자치도  서귀포시   대정읍
# 1        3849  스타벅스   성산일출봉점       음식   커피점/카페  제주특별자치도  서귀포시   성산읍
# 2        3854  스타벅스  신제주이마트점       음식   커피점/카페  제주특별자치도   제주시   노형동
# 3        7320  스타벅스    제주칠성점       음식   커피점/카페  제주특별자치도   제주시  일도1동
# 4        7451  스타벅스  제주용담DT점       음식   커피점/카페  제주특별자치도   제주시  용담2동
#
#           위도          경도
# 0  33.206761  126.290035
# 1  33.462859  126.935552
# 2  33.484956  126.480489
# 3  33.513338  126.525294
# 4  33.512386  126.484563

# %%
df_seoul_ediya = df_coffee[df_coffee['상호명'].str.contains('이디야')]
df_seoul_ediya.index = range(len(df_seoul_ediya))
print('서울시 내 이디야 점포 수 :', len(df_seoul_ediya))
df_seoul_ediya.head()
# Out:
# 서울시 내 이디야 점포 수 : 2065
#    Unnamed: 0         상호명         지점명 상권업종대분류명 상권업종중분류명      시도명  시군구명  행정동명  \
# 0        4246  이디야커피제주중문점       제주중문점       음식   커피점/카페  제주특별자치도  서귀포시   예래동
# 1        9319       이디야커피  에스프레소제주노형점       음식   커피점/카페  제주특별자치도   제주시   노형동
# 2       12589       이디야커피         삼도점       음식   커피점/카페  제주특별자치도   제주시  삼도1동
# 3       13424       이디야커피       제주한림점       음식   커피점/카페  제주특별자치도   제주시   한림읍
# 4       17105       이디야커피       제주화북점       음식   커피점/카페  제주특별자치도   제주시   화북동
#
#           위도          경도
# 0  33.254890  126.409829
# 1  33.489259  126.474851
# 2  33.504571  126.519739
# 3  33.418234  126.264367
# 4  33.518931  126.572549

# %%
starbucks_gu = df_seoul_starbucks.groupby('시군구명')['상호명'].count().to_frame().sort_values(by='상호명', ascending=False)
starbucks_gu = starbucks_gu.reset_index()
starbucks_gu = starbucks_gu.set_index('시군구명')
starbucks_gu
# Out:
#          상호명
# 시군구명
# 강남구       76
# 중구        74
# 서구        47
# 성남시 분당구   44
# 서초구       38
# ...      ...
# 산청군        1
# 부안군        1
# 보은군        1
# 청송군        1
# 횡성군        1
#
# [170 rows x 1 columns]

# %%
ediya_gu = df_seoul_ediya.groupby('시군구명')['상호명'].count().to_frame().sort_values(by='상호명', ascending=False)
ediya_gu = ediya_gu.reset_index()
ediya_gu = ediya_gu.set_index('시군구명')
ediya_gu
# Out:
#       상호명
# 시군구명
# 남구     56
# 서구     54
# 중구     50
# 북구     49
# 남양주시   43
# ...   ...
# 동해시     1
# 보령시     1
# 보은군     1
# 청도군     1
# 횡성군     1
#
# [217 rows x 1 columns]

# %%
from geopy.distance import great_circle
from utils import CountByWGS84
import pandas as pd
import folium

# %%
# 파라미터 설정
# 35.1613737 129.1479813
location.latitude, location.longitude
lat = location.latitude
lon = location.longitude
dist = 1
# 반경 집계 인스턴스 생성
cbw = CountByWGS84(df_food, lat, lon, dist)

# %%
# 반경 범위 내 데이터 필터링
result_radius = cbw.filter_by_radius()


plot_2 = cbw.plot_by_radius(result_radius)
plot_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_174f9222362257f627b79ee96645e31b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_174f9222362257f627b79ee96645e31b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_174f9222362257f627b79ee96645e31b = L.map(
#                 &quot;map_174f9222362257f627b79ee96645e31b&quot;,
#                 {
#                     center: [37.2541611, 127.0742492],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5b1a526473ef59f5b7935566d21f0445 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_174f9222362257f627b79ee96645e31b);
#
#
#             var marker_0e70ef800b6e93904edf77ce45b46b03 = L.marker(
#                 [37.2497452270599, 127.074322209269],
#                 {&quot;radius&quot;: 15}
#             ).addTo(map_174f9222362257f627b79ee96645e31b);
#
#
#             marker_0e70ef800b6e93904edf77ce45b46b03.bindTooltip(
#                 `&lt;div&gt;
#                      카페이응
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1d54c7de411e0f71e29558eabf9fc99b = L.marker(
#                 [37.2494886625281, 127.079555582574],
#                 {&quot;radius&quot;: 15}
#             ).addTo(map_174f9222362257f627b79ee96645e31b);
#
#
#             marker_1d54c7de411e0f71e29558eabf9fc99b.bindTooltip(
#                 `&lt;div&gt;
#                      노군맥주
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_549bfdf6550ed86bd7573d3892c41a97 = L.marker(
#                 [37.2524226889017, 127.077941740886],
#                 {&quot;radius&quot;: 15}
#             ).addTo(map_174f9222362257f627b79ee96645e31b);
#
#
#             marker_549bfdf6550ed86bd7573d3892c41a97.bindTooltip(
#                 `&lt;div&gt;
#                      삼척골뱅이
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_01deca0c550c817f74697001abe70b98 = L.marker(
#                 [37.2545969306221, 127.078275972919],
#                 {&quot;radius&quot;: 15}
#             ).addTo(map_174f9222362257f627b79ee96645e31b);
#
#
#             marker_01deca0c550c817f74697001abe70b98.bindTooltip(
#                 `&lt;div&gt;
#                      곤드레밥집
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3ffef853d8d1b128a0080e8fe646c47f = L.marker(
#                 [37.2510645441054, 127.075951823557],
#                 {&quot;radius&quot;: 15}
#             ).addTo(map_174f9222362257f627b79ee96645e31b);
#
#
#             marker_3ffef853d8d1b128a0080e8fe646c47f.bindTooltip(
#                 `&lt;div&gt;
#                      카페바이올렛
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7f14d6a5286b5efcba87547730b26ce5 = L.marker(
#                 [37.2513074968373, 127.074753989828],
#                 {&quot;radius&quot;: 15}
#             ).addTo(map_174f9222362257f627b79ee96645e31b);
#
#
#             marker_7f14d6a5286b5efcba87547730b26ce5.bindTooltip(
#                 `&lt;div&gt;
#                      비어캐빈영통점
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_cdf7405f2fd0e290097ba4749c5cb803 = L.marker(
#                 [37.2493122138798, 127.074259874231],
#                 {&quot;radius&quot;: 15}
#             ).addTo(map_174f9222362257f627b79ee96645e31b);
#
#
#             marker_cdf7405f2fd0e290097ba4749c5cb803.bindTooltip(
#                 `&lt;div&gt;
#                      천보헌갈비영통점
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a9277d38c9bc6c392907f1c472e26873 = L.marker(
#                 [37.2479601049718, 127.076508237355],
#                 {&quot;radius&quot;: 15}
#             ).addTo(map_174f9222362257f627b79ee96645e31b);
#
#
#             marker_a9277d38c9bc6c392907f1c472e26873.bindTooltip(
#                 `&lt;div&gt;
#                      오리진흙구이
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e1e496ce1622936db4a7274d7ec12a55 = L.marker(
#                 [37.257422878939, 127.074363547011],
#                 {&quot;radius&quot;: 15}
#             ).addTo(map_174f9222362257f627b79ee96645e31b);
#
#
#             marker_e1e496ce1622936db4a7274d7ec12a55.bindTooltip(
#                 `&lt;div&gt;
#                      아딸영통3호점
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_80347e41efb0d2fc482bc8920ed9cf80 = L.mark
